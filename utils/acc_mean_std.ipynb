# %% [markdown]
# 此文件按照 `B-m Inc-n ：m代表初始增量阶段类别数量，n代表后续每个增量阶段的类别数量` 统计的结果

# %% [markdown]
# ## cifar100

# %%
dataset = 'cifar100'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B50 Inc5','B50 Inc10']
# [[,,,,],[,,,,],[,,,,]]
inflora = [[89.68,92.14,93.25,69.65,74.92],[89.49,92.06,93.23,69.85,75.12],[89.47,91.83,93.19,70.01,75.33]]
aper = [[90.22,92.1,92.51,91.93,91.94],[90.22,92.15,92.52,91.95,91.96],[90.22,92.1,92.51,91.93,91.94]]
lae = [[81.94,90.7,91.33,88.12,90.4],[81.94,90.21,91.33,88.12,90.4],[81.94,90.7,91.33,88.12,90.4]]
coda_prompt = [[87.34,91.31,92.72,82.79,88.43],[87.34,91.31,92.72,82.79,88.43],[87.34,91.31,92.72,82.79,88.43]]
dual_prompt = [[88.39,90.38,91.38,80.8,87.38],[88.49,90.34,91.37,80.98,87.43],[88.43,90.23,91.36,80.71,87.44]]
finetune = [[72.72,76.91,81.3,80.1,82.46],[72.12,76.96,80.65,80.39,82.71],[72.12,76.96,80.65,80.39,82.71]]
der_cnn = [[88.57,88.58,88.78,86.56,86.83],[88.88,88.63,88.49,86.5,86.92],[88.57,88.58,88.78,86.56,86.83]]
der_nme = [[90.85,91.01,91.36,88.98,89.38],[91.14,91.13,91.08,88.79,89.37],[90.85,91.01,91.36,88.98,89.38]]
foster_cnn = [[94.02,93.86,93.67,92.03,92.21],[94.02,93.97,93.5,92.07,92.35],[94.02,93.86,93.67,92.03,92.21]]
foster_nme = [[94.19,94.08,93.59,92.13,92.21],[94.19,94.11,93.69,92.32,92.35],[94.19,94.08,93.59,92.13,92.21]]
icarl_cnn = [[84.61,85.99,87.04,81.65,83.37],[84.57,85.64,86.65,81.71,83.87],[84.61,85.99,87.04,81.65,83.37]]
icarl_nme = [[89.47,90.33,90.75,87.55,88.96],[89.63,90.23,90.42,87.54,89.01],[89.47,90.33,90.75,87.55,88.96]]
l2p = [[87.54,89.78,90.74,79.58,87.57],[87.57,89.8,90.74,79.36,87.67],[87.6,89.77,90.8,79.45,87.62]]
mos = [[93.42,94.68,94.8,94.15,94.09],[93.44,94.8,94.8,94.19,94.11],[93.44,94.8,94.8,94.19,94.11]]
ease = [[91.61,92.56,93.11,89.2,90.35],[91.65,92.59,93.07,89.29,90.47],[91.66,92.54,93.09,89.28,90.41]]
simple_cil = [[87.57,87.13,86.11,83.78,83.88],[87.58,87.14,86.12,83.81,83.9],[87.57,87.13,86.11,83.78,83.88]]

# %% [markdown]
# ## cub200

# %%
dataset = 'cub200'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B0 Inc40', 'B100 Inc5','B100 Inc10','B100 Inc20']
# [[,,,,,,],[,,,,,,],[,,,,,,]]
inflora = [[69.22,74.82,83.59,86.39,39.97,54.80,67.85],[69.97,74.33,83.71,86.19,39.27,54.75,67.77],[69.77,74.68,83.31,86.36,40.48,56.44,67.96]]
aper = [[92.52,92.27,92.06,91.82,89.64,89.66,89.73],[92.52,92.27,92.06,91.82,89.64,89.66,89.73],[92.52,92.27,92.06,91.82,89.64,89.66,89.73]]
lae = [[61.07,73.28,81.15,83.67,68.29,70.81,74.66],[61.07,73.28,81.15,83.67,68.29,70.81,74.66],[61.07,73.28,81.15,83.67,68.29,70.81,74.66]]
coda_prompt = [[71.59,83.25,84.65,85.65,69.65,77.88,82.44],[71.59,83.24,84.66,85.76,69.6,77.92,82.3],[71.59,83.25,84.65,85.65,69.65,77.88,82.44]]
dual_prompt = [[80.84,83.01,84.78,85.43,70.96,73.6,76.69],[80.77,83.04,84.82,85.36,71.06,73.73,76.65],[80.84,83.15,84.84,85.54,71.17,73.78,76.92]]
der_cnn = [[89.71,89.62,89.31,89.73,87.13,86.72,86.71],[89.89,89.56,89.01,88.94,87.01,87.24,86.87],[89.89,89.56,89.01,88.94,87.01,87.24,86.87]]
der_nme = [[90.6,91.08,90.43,89.82,87.86,88.23,88.54],[90.59,90.46,89.68,89.76,87.82,88.31,88.27],[90.59,90.46,89.68,89.76,87.82,88.31,88.27]]
foster_cnn = [[87.08,86.03,80.7,78.55,86.83,85.97,82.98],[87.78,85.4,81.97,78.34,87.11,85.6,82.88],[87.08,86.03,80.7,78.55,86.83,85.97,82.98]]
foster_nme = [[91.09,91.89,91.05,90.58,88.98,89.18,89.17],[91.66,91.3,91.34,91.01,88.96,88.83,88.76],[91.09,91.89,91.05,90.58,88.98,89.18,89.17]]
finetune = [[44.85,65.45,71.39,78.61,46.86,62.67,73.24],[45.57,64.7,69.83,78.51,46.07,63.61,73.36],[2.96,64.7,69.83,78.51,46.07,63.61,73.36]]
icarl_cnn = [[87.83,88.07,88.27,87.42,84.5,85.47,85.9],[87.83,88.23,88.46,87.68,84.4,85.37,85.71],[87.83,88.07,88.27,87.42,84.5,85.47,85.9]] 
icarl_nme = [[90.12,89.9,90.13,89.12,87.32,87.53,88.11],[90.12,90.78,90.05,88.73,86.88,87.74,88.14],[90.12,89.9,90.13,89.12,87.32,87.53,88.11]]
l2p = [[71.58,79.24,81.8,83.79,70.68,74.62,79.42],[71.63,79.32,81.76,83.79,70.69,74.62,79.4],[71.68,79.26,81.83,83.75,70.63,74.62,79.41]]
mos = [[93.78,93.53,93.27,92.53,91.5,91.35,91.4],[93.78,93.53,93.23,92.5,91.54,91.41,91.49],[93.78,93.53,93.23,92.5,91.54,91.41,91.49]]
ease = [[92.3,91.34,90.18,90.16,86.01,87.47,85.28],[92.31,91.32,90.2,90.14,86.05,87.4,85.26],[92.3,91.34,90.19,90.2,86.15,87.54,85.29]]
simple_cil = [[92.48,92.23,91.85,91.29,88.98,88.99,89.05],[92.23,92.23,91.85,91.29,88.98,88.99,89.05],[92.48,92.23,91.85,91.29,88.98,88.99,89.05]]

# %% [markdown]
# ## inr

# %%
dataset = 'inr'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B0 Inc40', 'B100 Inc5','B100 Inc10','B100 Inc20']
# [[,,,,,,],[,,,,,,],[,,,,,,]]
inflora = [[72.65,80.24,83.00,82.91,51.27,58.51,65.62],[72.53,79.91,83.00,83.02,51.27,58.51,65.62],[73.68,79.59,83.18,83.37,50.83,58.88,65.69]]
aper = [[71.19,74.43,75.19,75.28,73.96,73.93,74.01],[71.19,74.25,75.14,75.28,74.04,74.02,74.08],[71.19,74.43,75.19,75.28,73.96,73.93,74.01]]
lae = [[58.95,70.41,75.54,76.57,60.92,67.13,70.7],[58.95,70.41,75.64,76.57,60.92,67.13,70.7],[58.83,70.41,75.54,76.57,60.92,67.13,70.7]]
coda_prompt = [[59.61,72.47,78.15,80.43,65.82,71.55,75.2],[59.61,72.49,78.21,80.51,65.92,71.72,75.12],[59.61,72.47,78.15,80.43,65.82,71.55,75.2]]
dual_prompt = [[63.11,69.92,70.97,73.51,54.97,59.55,64.82],[63.21,69.84,71.04,73.61,55.24,59.71,64.93],[62.91,69.94,71.09,73.61,55.3,59.82,64.96]]
l2p = [[70.46,73.76,76.18,76.71,59.6,64.95,69.83],[70.55,73.7,76.26,76.85,59.55,64.89,69.7],[70.42,73.81,76.25,76.73,59.59,64.83,69.64]]
finetune = [[56.87,64.07,69.06,72.36,57.33,67.54,70.82],[56.4,63.66,69.02,72.11,63.19,66.92,70.6],[56.4,63.66,69.02,72.11,63.19,66.92,70.6]]
mos = [[77.18,81.32,82.46,82.82,80.97,81.04,81.06],[77.1,81.26,82.62,82.67,81.03,81.11,81.05],[77.1,81.14,82.54,82.67,81.01,81.06,81.05]]
ease = [[67.81,78.99,81.06,81.5,71.4,76.54,77.96],[67.81,78.93,80.87,81.48,71.39,76.64,78.04],[67.81,78.9,80.92,81.6,71.4,76.59,77.95]]
simple_cil = [[62.39,61.83,61.12,59.7,56.7,56.7,56.82],[62.47,61.9,61.18,59.76,56.72,56.71,56.84],[62.39,61.83,61.12,59.7,56.7,56.7,56.82]]

# %% [markdown]
# ## ina

# %%
dataset = 'ina'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B0 Inc40', 'B100 Inc5','B100 Inc10','B100 Inc20']
# [[,,,,,,],[,,,,,,],[,,,,,,]]
inflora = [[40.90,52.03,58.21,62.85,32.78,43.75,51.10],[40.32,50.77,59.65,63.71,34.23,42.74,51.08],[40.32,50.77,59.65,63.71,34.23,42.74,51.08]]
aper = [[61.24,60.69,60.02,60.0,61.36,61.4,61.48],[61.24,60.69,60.02,60.0,61.36,61.4,61.48],[61.24,60.69,60.02,60.0,61.36,61.4,61.48]]
lae = [[26.87,38.31,48.61,54.76,45.25,48.73,51.35],[26.87,38.31,48.61,54.76,45.25,48.73,51.35],[26.87,38.31,48.61,54.76,45.25,48.73,51.35]]
dual_prompt = [[43.6,48.44,52.47,54.01,43.44,44.59,46.87],[43.66,48.57,52.6,54.03,43.46,44.52,47.02],[43.6,48.44,52.47,54.01,43.44,44.59,46.87]]
l2p = [[37.89,45.73,52.48,53.14,44.62,46.62,48.98],[37.85,45.79,52.39,53.16,44.55,46.62,49.12],[37.85,45.79,52.39,53.16,44.55,46.62,49.12]]
finetune = [[22.02,4.81,12.29,40.3,21.48,25.43,29.5],[22.39,25.71,12.61,37.41,20.6,25.07,29.54],[22.39,25.71,12.61,37.41,20.6,25.07,29.54]]
mos = [[64.26,64.29,67.13,65.43,64.67,65.0,64.96],[64.26,64.29,60.87,65.42,64.52,64.84,64.87],[64.26,64.29,60.87,65.42,64.52,64.84,64.87]]
ease = [[60.21,57.68,62.68,67.75,62.08,62.19,63.04],[60.12,57.72,62.45,67.69,62.26,62.68,63.36],[60.21,57.68,62.68,67.75,62.08,62.19,63.04]]
simple_cil = [[61.21,60.64,59.82,58.3,53.0,53.06,53.14],[61.21,60.64,59.82,58.3,53.0,53.06,53.14],[61.21,60.64,59.82,58.3,53.0,53.06,53.14]]

# %% [markdown]
# ## omn

# %%
# 1st-omn 2nd-omn 3rd-omn-std顺序统计
dataset = 'omn'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B0 Inc30', 'B150 Inc5','B150 Inc10','B150 Inc30']
# [[,,,,,,],[,,,,,,],[,,,,,,]]
inflora = [[68.13,71.19,76.33,77.44,52.82,58.71,66.41],[67.13,71.43,76.33,77.44,52.82,58.71,66.29],[68.49,71.26,76.09,77.26,52.64,59.03,66.29]]
aper = [[80.36,80.1,80.31,80.7,77.4,77.42,77.57],[80.36,80.1,80.31,80.58,77.42,77.44,77.59],[80.36,80.1,80.31,80.7,77.4,77.42,77.57]]
lae = [[53.43,69.11,74.58,76.17,59.65,63.41,73.53],[53.43,68.49,74.58,76.17,59.65,63.41,73.53],[53.43,69.11,74.58,76.17,59.65,63.41,73.53]]
coda_prompt = [[69.78,74.41,76.9,77.79,63.22,65.65,72.32],[69.78,74.41,76.9,77.79,63.22,65.65,72.32],[69.78,74.41,76.9,77.79,63.22,65.65,72.32]]
dual_prompt = [[69.2,73.65,75.93,74.99,57.43,60.18,71.87],[69.29,73.53,75.89,74.92,57.44,60.18,71.73],[69.33,73.66,75.83,74.99,57.43,60.18,71.87]]
der_cnn = [[75.73,76.75,77.31,77.53,75.95,76.8,76.48],[75.73,76.72,77.12,77.53,76.16,76.8,76.48,],[75.73,76.72,77.12,77.76,76.16,76.5,76.72,]]
der_nme = [[77.16,78.9,80.4,80.74,76.85,77.67,79.17],[77.16,78.99,80.34,80.74,77.23,77.67,79.17],[77.16,78.99,80.34,81.28,77.23,77.81,79.12]]
foster_cnn = [[81.1,81.59,80.24,78.91,79.93,80.06,78.59],[81.25,81.48,80.2,79.13,79.83,80.28,78.82],[81.1,81.59,80.24,78.91,79.93,80.06,78.59]]
foster_nme = [[81.91,83.26,83.24,83.41,80.69,81.21,81.57],[82.22,83.0,83.22,83.14,80.34,81.06,81.7],[81.91,83.26,83.24,83.41,80.69,81.21,81.57]]
finetune = [[48.23,56.84,62.93,66.03,55.67,63.18,68.16],[48.6,56.98,63.12,65.78,55.83,63.13,68.36],[48.6,56.98,63.12,65.78,55.83,63.13,68.36]]
icarl_cnn = [[71.7,73.94,75.08,75.26,70.83,72.11,74.39],[71.44,73.26,74.62,74.63,70.64,72.0,74.02],[71.7,73.94,75.08,75.26,70.83,72.11,74.39]] 
icarl_nme = [[77.33,79.77,81.25,80.94,75.85,77.4,79.13],[76.65,79.53,81.3,81.1,75.66,77.38,79.35],[77.33,79.77,81.25,80.94,75.85,77.4,79.13]]
l2p = [[69.13,70.91,74.17,74.18,58.27,60.47,70.4],[69.12,70.95,74.15,74.14,58.28,60.31,70.38],[69.02,70.94,73.93,74.1,58.33,60.25,70.19]]
mos = [[85.92,85.79,85.95,85.95,83.0,83.25,83.46],[85.92,85.8,86.1,85.86,83.03,83.25,83.52],[85.92,85.79,85.99,85.83,83.05,83.26,83.52]]
ease = [[73.92,74.26,75.43,74.81,68.85,68.05,71.7],[73.85,74.3,75.44,74.85,68.83,68.0,71.66],[73.89,74.36,75.42,74.77,68.91,68.1,71.71]]
simple_cil = [[80.54,80.27,80.07,79.36,75.23,75.26,75.44],[80.52,80.25,80.06,79.34,75.22,75.25,75.42],[80.54,80.27,80.07,79.36,75.23,75.26,75.44]]

# %% [markdown]
# ## vtab

# %%
dataset = 'vtab'
positions = ['B0 Inc5', 'B0 Inc10']
inflora = [[81.85,89.54],[81.85,89.54],[82.62,90.01]]
aper =  [[86.96,86.25],[86.96,86.25],[86.96,86.25]]
lae = [[69.31,84.94],[69.31,84.94],[69.31,84.94]]
mos = [[95.77,96.22],[96.25,95.76],[96.22,95.77]]
ease = [[90.79,90.79],[90.78,90.45],[90.79,90.45]]
simple_cil = [[91.35,90.8],[91.35,90.8],[91.35,90.8]]
dual_prompt = [[87.46,89.78],[87.46,89.9],[87.46,89.78]]
coda_prompt = [[80.44,87.24],[80.44,87.24],[80.44,87.24]]
l2p = [[77.47,81.71],[77.46,81.7],[77.47,81.71]]
finetune = [[63.55,78.67],[59.26,81.86],[59.26,81.86]]

# %% [markdown]
# ## 绘图-Markdown版

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义一个函数来计算均值和方差
def calc_mean_std(data):
    mean_values = np.around(np.mean(data, axis=0), decimals=2)
    std_values = np.around(np.std(data, axis=0), decimals=2)
    return mean_values.tolist(), std_values.tolist()
# 计算每个模型的均值和方差(无记忆回放的方法)
inflora_mean, inflora_std = calc_mean_std(inflora)
aper_mean, aper_std = calc_mean_std(aper)
lae_mean, lae_std = calc_mean_std(lae)
mos_mean, mos_std = calc_mean_std(mos)
ease_mean, ease_std = calc_mean_std(ease)
coda_prompt_mean, coda_prompt_std = calc_mean_std(coda_prompt)
dual_prompt_mean, dual_prompt_std = calc_mean_std(dual_prompt)
l2p_mean, l2p_std = calc_mean_std(l2p)
simple_cil_mean, simple_cil_std = calc_mean_std(simple_cil)
finetune_mean, finetune_std = calc_mean_std(finetune)
# print("|Inflora", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(inflora_mean, inflora_std)]) + "|")
print("|APER", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(aper_mean, aper_std)]) + "|")
# print("|MOS", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(mos_mean, mos_std)]) + "|")
# print("|Ease", "|" + "| ".join([f"{mean} ± {std}" for mean, std in zip(ease_mean, ease_std)]) + "|")
# print("|LAE", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(lae_mean, lae_std)]) + "|")
# print("|CODA-Prompt", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(coda_prompt_mean, coda_prompt_std)]) + "|")
# print("|DualPrompt", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(dual_prompt_mean, dual_prompt_std)]) + "|")
# print("|L2P", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(l2p_mean, l2p_std)]) + "|")
# print("|SimpleCIL", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(simple_cil_mean, simple_cil_std)]) + "|")
# print("|Finetune", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(finetune_mean, finetune_std)]) + "|")    
  
marker = ['o', 's', 'D', '^',  '>',  'p', 'h','<','v','*','+', 'x', 'D', 'd', '|', '_']
colors = ['#43978F', "#9467bd",'#ED9F9B','#84C2AE', '#E56F5E', '#F6C957','#589CD6', '#FFB77F',"#17becf",'#BD514A','#AED185', '#EF7E33', '#B395BD', '#F9F871', '#FFB6C1', '#FF7F0E', '#2CA02C']

datasets = [
    ('InfLoRA', inflora_mean),
    ('APER', aper_mean),
    ('LAE', lae_mean),
    ('MOS', mos_mean),
    ('EASE', ease_mean),
    ('CODA-Prompt', coda_prompt_mean),
    ('Dual-Prompt', dual_prompt_mean),
    ('L2P', l2p_mean),
    ('Simple-CIL', simple_cil_mean),
    ('Fine-tune', finetune_mean)
]

if dataset == 'inr' or dataset == 'ina' or dataset == 'vtab':
    pass # memory方法在这三个数据集上没有结果
else:
    # if dataset == 'omn':
    #     positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20','B0 Inc30','B150 Inc5','B150 Inc10']
    # else:
    #     positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B0 Inc40', 'B100 Inc5','B100 Inc10','B100 Inc20']
    # coil_mean, coil_std = calc_mean_std(coil)
    foster_cnn_mean, foster_cnn_std = calc_mean_std(foster_cnn)
    foster_nme_mean, foster_nme_std = calc_mean_std(foster_nme)
    der_cnn_mean, der_cnn_std = calc_mean_std(der_cnn)
    der_nme_mean, der_nme_std = calc_mean_std(der_nme)
    icarl_cnn_mean, icarl_cnn_std = calc_mean_std(icarl_cnn)
    icarl_nme_mean, icarl_nme_std = calc_mean_std(icarl_nme)
    # datasets.append(('COIL', coil_mean))
    datasets.append(('Foster-CNN', foster_cnn_mean))
    datasets.append(('Foster-NME', foster_nme_mean))
    datasets.append(('DER-CNN', der_cnn_mean))
    datasets.append(('DER-NME', der_nme_mean))
    datasets.append(('iCaRL-CNN', icarl_cnn_mean))
    datasets.append(('iCaRL-NME', icarl_nme_mean))
    # print("|COIL", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(coil_mean, coil_std)]) + "|")
    # print("|FOSTER-CNN", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(foster_cnn_mean, foster_cnn_std)]) + "|")
    # print("|FOSTER-NME", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(foster_nme_mean, foster_nme_std)]) + "|")
    # print("|DER-CNN", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(der_cnn_mean, der_cnn_std)]) + "|")
    # print("|DER-NME", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(der_nme_mean, der_nme_std)]) + "|")
    # print("|iCaRL-CNN", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(icarl_cnn_mean, icarl_cnn_std)]) + "|")
    # print("|iCaRL-NME", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(icarl_nme_mean, icarl_nme_std)]) + "|")
    
plt.figure(dpi=300, figsize=(4, 3))  # 设置图表分辨率和尺寸
i = 0
for name, data in datasets:  
    plt.plot(positions,data,label=name,marker=marker[i],color = colors[i], markersize=2,linewidth=1)  
    i+=1
  
# 设置图表标题和坐标轴标签  
# plt.xlabel('Inc', fontsize=6)  
plt.ylabel('Accuracy(%)', fontsize=6)  

plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
  
# 设置图例  
plt.legend(fontsize=5,loc='lower left',ncol=2)  # 设置图例位置 
  
# 显示网格  
# plt.grid(True)  
  
# 调整x轴刻度，使数据点更易读  
# plt.xticks(param_counts_backbone, positions, rotation=45)  
  
# 显示图表  
plt.show()
# Out:
# |APER |86.96 ± 0.0|86.25 ± 0.0|

# %% [markdown]
# ## 绘图-计算版

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义一个函数来计算均值和方差
def calc_mean_std(data):
    mean_values = np.around(np.mean(data, axis=0), decimals=2)
    std_values = np.around(np.std(data, axis=0), decimals=2)
    return mean_values.tolist(), std_values.tolist()
# 计算每个模型的均值和方差
ease_mean, ease_std = calc_mean_std(ease)
coda_prompt_mean, coda_prompt_std = calc_mean_std(coda_prompt)
dual_prompt_mean, dual_prompt_std = calc_mean_std(dual_prompt)
l2p_mean, l2p_std = calc_mean_std(l2p)
simple_cil_mean, simple_cil_std = calc_mean_std(simple_cil)
finetune_mean, finetune_std = calc_mean_std(finetune)
print("ease:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(ease_mean, ease_std)]) + "]")
print("coda_prompt:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(coda_prompt_mean, coda_prompt_std)]) + "]")
print("dual_prompt:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(dual_prompt_mean, dual_prompt_std)]) + "]")
print("l2p:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(l2p_mean, l2p_std)]) + "]")
print("simple_cil:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(simple_cil_mean, simple_cil_std)]) + "]")
print("finetune:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(finetune_mean, finetune_std)]) + "]")    
# print("coda_prompt:", coda_prompt_mean, coda_prompt_std)
# print("dual_prompt:", dual_prompt_mean, dual_prompt_std)
# print("l2p:", l2p_mean, l2p_std)
# print("simple_cil:", simple_cil_mean, simple_cil_std)
# print("finetune:", finetune_mean, finetune_std)
  
marker = ['o', 's', 'D', '^',  '>',  'p', 'h','<','v','*','+', 'x', 'D', 'd', '|', '_']
colors = ['#43978F', '#9EC4BE', '#B192B4', '#E56F5E', '#F6C957','#589CD6', '#E57259','#FFB77F','#BD514A','#AAD390', '#EF7E33', '#F7C242', '#F9F871']

datasets = [  
    ('EASE', ease_mean),
    ('CODA-Prompt', coda_prompt_mean),
    ('Dual-Prompt', dual_prompt_mean),
    ('L2P', l2p_mean),
    ('Simple-CIL', simple_cil_mean),
    ('Fine-tune', finetune_mean)
]
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B50 Inc5','B50 Inc10']
if dataset == 'inr' or dataset == 'ina' or dataset == 'vtab':
    if dataset == 'vtab':
        positions = ['B0 Inc5', 'B0 Inc10']
else:
    foster_cnn_mean, foster_cnn_std = calc_mean_std(foster_cnn)
    foster_nme_mean, foster_nme_std = calc_mean_std(foster_nme)
    der_cnn_mean, der_cnn_std = calc_mean_std(der_cnn)
    der_nme_mean, der_nme_std = calc_mean_std(der_nme)
    icarl_cnn_mean, icarl_cnn_std = calc_mean_std(icarl_cnn)
    icarl_nme_mean, icarl_nme_std = calc_mean_std(icarl_nme)
    datasets.append(('Foster-CNN', foster_cnn_mean))
    datasets.append(('Foster-NME', foster_nme_mean))
    datasets.append(('DER-CNN', der_cnn_mean))
    datasets.append(('DER-NME', der_nme_mean))
    datasets.append(('iCaRL-CNN', icarl_cnn_mean))
    datasets.append(('iCaRL-NME', icarl_nme_mean))
    print("Foster-CNN:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(foster_cnn_mean, foster_cnn_std)]) + "]")
    print("Foster-NME:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(foster_nme_mean, foster_nme_std)]) + "]")
    print("DER-CNN:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(der_cnn_mean, der_cnn_std)]) + "]")
    print("DER-NME:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(der_nme_mean, der_nme_std)]) + "]")
    print("iCaRL-CNN:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(icarl_cnn_mean, icarl_cnn_std)]) + "]")
    print("iCaRL-NME:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(icarl_nme_mean, icarl_nme_std)]) + "]")
    # print("Foster-CNN:", foster_cnn_mean, foster_cnn_std)
    # print("Foster-NME:", foster_nme_mean, foster_nme_std)
    # print("DER-CNN:", der_cnn_mean, der_cnn_std)
    # print("DER-NME:", der_nme_mean, der_nme_std)
    # print("iCaRL-CNN:", icarl_cnn_mean, icarl_cnn_std)
    # print("iCaRL-NME:", icarl_nme_mean, icarl_nme_std)
    
plt.figure(dpi=300, figsize=(4, 3))  # 设置图表分辨率和尺寸
i = 0
for name, data in datasets:  
    plt.plot(positions,data,label=name,marker=marker[i],color = colors[i], markersize=2,linewidth=1)  
    i+=1
  
# 设置图表标题和坐标轴标签  
# plt.xlabel('Inc', fontsize=6)  
plt.ylabel('Accuracy(%)', fontsize=6)  

plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
  
# 设置图例  
plt.legend(fontsize=5,loc='lower left',ncol=2)  # 设置图例位置 
  
# 显示网格  
# plt.grid(True)  
  
# 调整x轴刻度，使数据点更易读  
# plt.xticks(param_counts_backbone, positions, rotation=45)  
  
# 显示图表  
plt.show()
# Out:
# ease: [90.14 ± 0.05, 90.21 ± 0.01, 91.32 ± 0.01, 85.26 ± 0.02, 87.44 ± 0.07]
# coda_prompt: [85.78 ± 0.09, 84.93 ± 0.05, 83.03 ± 0.08, 79.59 ± 0.03, 76.44 ± 0.14]
# dual_prompt: [85.5 ± 0.03, 84.84 ± 0.04, 82.9 ± 0.08, 77.01 ± 0.07, 73.8 ± 0.1]
# l2p: [83.74 ± 0.04, 81.8 ± 0.05, 79.33 ± 0.01, 79.15 ± 0.18, 74.65 ± 0.02]
# simple_cil: [89.92 ± 0.0, 90.57 ± 0.01, 90.96 ± 0.0, 87.51 ± 0.04, 87.43 ± 0.04]
# finetune: [77.36 ± 0.49, 70.94 ± 0.74, 60.21 ± 2.64, 72.88 ± 0.42, 62.32 ± 2.26]
# Foster-CNN: [78.81 ± 0.53, 81.18 ± 0.36, 85.17 ± 0.64, 82.65 ± 0.25, 85.56 ± 0.01]
# Foster-NME: [90.65 ± 0.05, 91.02 ± 0.16, 91.4 ± 0.34, 88.92 ± 0.18, 88.72 ± 0.02]
# DER-CNN: [89.08 ± 0.48, 88.71 ± 0.86, 90.13 ± 0.05, 87.14 ± 0.2, 86.72 ± 0.06]
# DER-NME: [89.89 ± 0.19, 89.43 ± 0.71, 90.99 ± 0.05, 88.62 ± 0.11, 88.34 ± 0.21]
# iCaRL-CNN: [87.77 ± 0.25, 88.2 ± 0.13, 88.2 ± 0.36, 85.93 ± 0.32, 85.4 ± 0.42]
# iCaRL-NME: [89.06 ± 0.04| 89.94 ± 0.13| 90.2 ± 0.21| 87.91 ± 0.14| 87.25 ± 0.28]
